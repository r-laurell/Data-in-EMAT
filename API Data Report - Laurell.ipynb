# %% [markdown]
# ## Spotify API Report - Reanna Laurell
#
# ### Hypotheses
# My hypotheses is that based on Taylor Swift's recent attention in the NFL, her world tour, and concert movie coming out, that her songs have more streams that any other artist on spotify right now based on the top five most streamed artists from 2022, placing her at the new top streamed artists in 2023 based on the popularity API for Spotify.
#
# My I am assuming that Taylor Swift is gaining streams on Spotify right now because of her recent attention in the NFL but also she has her concert movie coming out Friday October 13. I am thinking that based on these two recent events, she her streams will put her ahead of other artists on spotify right now.
#
# Statistically thinking, Taylor Swift was the second streamed artist of 2022 on Spotify, with the recent events in mind, her recent concert tour that went around the United States this past year, and the release of a few different albums this year leave me to think that with these events it could put her at the number one streamed artist this year.

# %% [markdown]
# I will be using the endpoints get several artists and get artists top tracks to test this hypothesis. I believe that these will help me to test my hypothesis because the get several artists will allow me to get the top five artists from 2022 and compare them on a dataframe. The get artists top tracks will be able to help me compare the differences between their songs as well giving me further details into the artists by using the popularity integer.
#
# This data will be reliable because I am using the top artists from 2022 that Spotify came out with however this could be unreliable as the artists ratings could've changed a lot from last year to this year.
#
# The limitations that might alter my ability to test my hypothesis will be if I can not find a way to compare the most streamed songs from each artist that I plan on looking at.

# %%
import requests
import pandas as pd
import base64
import json
import urllib

# %% [markdown]
# Bringing in the client id and secret numbers in order to access my spotify account code

# %%
Client_ID = pd.read_csv('Spotify_Keys_9-19-2023.txt')['Client_ID'].iloc[0]

# %%
Client_Secret = pd.read_csv('Spotify_Keys_9-19-2023.txt')['Client_Secret'].iloc[0]

# %% [markdown]
# Commenting out the numbers in order to never show the actual numbers given from Spotify

# %%
# Client_ID

# %%
# Client_Secret

# %% [markdown]
# any string can be changed on the fly by adding in the {} with a dot format, can have multiple of the placeholders

# %%
client_cred = base64.b64encode(str(Client_ID + ":" + Client_Secret).encode("ascii"))

# %%
# client_cred

# %%
headers = {"Authorization": "Basic {}".format(client_cred.decode("ascii"))}

# %%
# headers

# %%
payload = {'grant_type' : 'client_credentials'}
url = 'https://accounts.spotify.com/api/token'

# %%
session_key_response = requests.post(url = url, data = payload, headers = headers)

# %%
session_key_response.status_code
# Out:
# 200

# %%
# session_key_response.json()['access_token']

# %%
session_header_key = session_key_response.json()

# %%
key = session_header_key['access_token']

# %%
session_headers = {"Authorization" : "Bearer {}".format(key)}

# %%
# session_headers

# %% [markdown]
# Adding in the artists id

# %%
taylor_swift_id = '06HL4z0CvFAxyc27GXpf02'

# %%
bad_bunny_id = '4q3ewBCX7sLwd24euuV69X'

# %%
drake_id = '3TVXtAsR1Inumwj472S9r4'

# %%
the_weekend_id = '1Xyo4u8uXC1ZmMpatF05PJ'

# %%
bts_id = '3Nrfpe0tUJi4K4DXYWgMUX'

# %% [markdown]
# Using the get several artists to get all the artists information

# %%
artists_id = 'https://api.spotify.com/v1/artists?ids=06HL4z0CvFAxyc27GXpf02,4q3ewBCX7sLwd24euuV69X,3TVXtAsR1Inumwj472S9r4,1Xyo4u8uXC1ZmMpatF05PJ,3Nrfpe0tUJi4K4DXYWgMUX'

# %%
artist_response = requests.get(url = artists_id, headers = session_headers)
artist_response.status_code
# Out:
# 200

# %%
artist_data = artist_response.json()

# %% [markdown]
# Looking at the different keys for the artists data

# %%
artist_data.keys()
# Out:
# dict_keys(['artists'])

# %%
artist_data['artists'][0].keys()
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])

# %%
artist_data['artists'][0]['popularity']
# Out:
# 100

# %% [markdown]
# Creating a data frame to display all the artists information to compare the artists together

# %%
artist_df = pd.DataFrame(artist_data['artists'])

# %% [markdown]
# From the data frame below, we are able to see that the top to artists bases on popularity, is Taylor Swift with 100 and Drake with 97. This is different from Spotify's top 2022 list as Bad Bunny was number one and Taylor Swift was number two.

# %%
artist_df.sort_values('popularity', ascending = False)
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/0...
# 2  {'spotify': 'https://open.spotify.com/artist/3...
# 1  {'spotify': 'https://open.spotify.com/artist/4...
# 3  {'spotify': 'https://open.spotify.com/artist/1...
# 4  {'spotify': 'https://open.spotify.com/artist/3...
#
#                            followers  \
# 0  {'href': None, 'total': 89368616}
# 2  {'href': None, 'total': 81206966}
# 1  {'href': None, 'total': 75700919}
# 3  {'href': None, 'total': 73083021}
# 4  {'href': None, 'total': 70488765}
#
#                                               genres  \
# 0                                              [pop]
# 2  [canadian hip hop, canadian pop, hip hop, pop ...
# 1            [reggaeton, trap latino, urbano latino]
# 3     [canadian contemporary r&b, canadian pop, pop]
# 4                      [k-pop, k-pop boy group, pop]
#
#                                                 href                      id  \
# ...

# %% [markdown]
# Getting the top two artists based on their popularity

# %%
top_artists_id = 'https://api.spotify.com/v1/artists?ids=06HL4z0CvFAxyc27GXpf02,3TVXtAsR1Inumwj472S9r4'

# %%
top_artist_response = requests.get(url = top_artists_id, headers = session_headers)
top_artist_response.status_code
# Out:
# 200

# %%
top_artist_data = top_artist_response.json()

# %%
top_artist_df = pd.DataFrame(top_artist_data['artists'])

# %% [markdown]
# Displaying the new information in a data frame to compare them easier

# %%
top_artist_df
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/0...
# 1  {'spotify': 'https://open.spotify.com/artist/3...
#
#                            followers  \
# 0  {'href': None, 'total': 89368616}
# 1  {'href': None, 'total': 81206966}
#
#                                               genres  \
# 0                                              [pop]
# 1  [canadian hip hop, canadian pop, hip hop, pop ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/06HL4z0CvFA...  06HL4z0CvFAxyc27GXpf02
# 1  https://api.spotify.com/v1/artists/3TVXtAsR1In...  3TVXtAsR1Inumwj472S9r4
#
#                                               images          name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Taylor Swift
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...         Drake
#
#    popularity    type                                    uri
# ...

# %% [markdown]
# Getting Taylor Swifts top tracks from Spotify

# %%
top_track_id = 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02/top-tracks?market=US'

# %%
top_track_id
# Out:
# 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02/top-tracks?market=US'

# %%
top_track_response = requests.get(url = top_track_id, headers = session_headers)
top_track_response.status_code
# Out:
# 200

# %%
top_track_response.json()
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#     'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#     'id': '1NAmidJlEaVgA3MpcPFYGq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#       'width': 64}],
# ...

# %%
top_track = top_track_response.json()

# %% [markdown]
# Looking at the different keys for top track

# %%
top_track.keys()
# Out:
# dict_keys(['tracks'])

# %% [markdown]
# looking at the json file for Taylor Swifts top tracks

# %%
# top_track['tracks']

# %%
top_track['tracks'][0]['popularity']
# Out:
# 99

# %%
top_track_df = pd.DataFrame(top_track['tracks'])

# %% [markdown]
# Displaying the Taylor Swifts top tracks in a data frame, we can see that the most popular song of hers is Cruel Summer with 99 popularity.

# %%
top_track_df.sort_values('popularity', ascending = False)
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %% [markdown]
# Getting Drake's top tracks from spotify

# %%
top_track_id_Drake = 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4/top-tracks?market=US'

# %%
top_track_Drake_response = requests.get(url = top_track_id_Drake, headers = session_headers)
top_track_Drake_response.status_code
# Out:
# 200

# %% [markdown]
# Looking at Drake's top tracks json file

# %%
# top_track_Drake_response.json()

# %%
top_track_Drake = top_track_Drake_response.json()

# %%
type(top_track_Drake['tracks'])
# Out:
# list

# %%
top_track_Drake_df = pd.DataFrame(top_track_Drake['tracks'])

# %% [markdown]
# Displaying Drake's top tracks in a data frame we can see that his top song is Meltdown with a popularity of 91.

# %%
top_track_Drake_df.sort_values('popularity', ascending = False)
# Out:
#                                                album  \
# 2  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %% [markdown]
# Concat the top tracks of Taylor Swift and Drake to one data frame, link cited down below

# %%
joined_df = pd.concat([top_track_df, top_track_Drake_df], ignore_index = True)

# %%
joined_df.columns
# Out:
# Index(['album', 'artists', 'disc_number', 'duration_ms', 'explicit',
#        'external_ids', 'external_urls', 'href', 'id', 'is_local',
#        'is_playable', 'name', 'popularity', 'preview_url', 'track_number',
#        'type', 'uri'],
#       dtype='object')

# %%
joined_df.shape
# Out:
# (20, 17)

# %% [markdown]
# Displaying the combined data frame and sorting by popularity

# %%
joined_df.sort_values('popularity', ascending = False).head()
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       178426     False  {'isrc': 'USUG11901472'}
# 3       200690     False  {'isrc': 'USUG12205736'}
# 4       261922     False  {'isrc': 'USUG12002842'}
# ...

# %% [markdown]
# ## Conclusion
#
# In conclusion, I found that my hypothesis was correct in that Taylor Swift has jumped from the second spot in Spotify's top artists for 2022 to number one. I also found that the Drake jumped to the second spot, knocking Bad Bunny to the third spot on the list.
#
# When looking at the top two artists top songs, I found that Taylor Swift holds four of the five songs. This didn't surprise me as the number one top song based on popularity was Cruel Summer, which just recently was rereleased as a single after the orginial album came out in 2019, due to it's popularity and streaming levels. The second highest song based on popularity was from her new album Midnights, showing that the part of my hypotheses where her new album helped up her popularity might have been correct.
#
# I was also surpised to find that MELTDOWN, the song that Drake is featured in, isn't even his song, it is Travis Scott song. When looking at all of the top songs and not just the head, a lot of Drake's songs that made the list had other artists on the track with him. I don't really listen to Drake much, so maybe this is normal for him, but I thought that was surprising to find.

# %% [markdown]
# ## Reflection
# One of the limitations that I had when coding this analysis was attempting to make my dataframes look nicer with list comprehension. I wanted to change the artists column in the joined dataframe to be the name of the artist for the song. However, I found that I still do not have a good understanding of how to complete list comphrension so I have decided to just list the artists here incase of confusion.
#
# Top Songs: &nbsp;
# 1.) Cruel Summer - Taylor Swift &nbsp;
# 2.) Anti-Hero - Taylor Swift &nbsp;
# 3.) August - Taylor Swift &nbsp;
# 4.) MELTDOWN (feat. Drake) - Travis Scott &nbsp;
# 5.) Cardigan - Taylor Swift
#
# ### Alternative Approaches
# A possible alternative approach to solving this hypotheses might have been to see if you could find the top artist without using a list of the years previous. This would allow for you to have the true top artist for the year instead of assuming the top five haven't changed.
#
# ### Potention Next Steps
# Some potention next steps that could be done with this data would be to look at different API calls to find out what might make one song or artist more liked than the next. It could maybe the amount of time an artist has been making music for, or the number of explict words in a song, the dancability of a song or a different factor.
#
# ### Link Citations
# Concat funtion
# https://www.geeksforgeeks.org/pandas-concat-function-in-python/  &nbsp;
# Spotify's top artists
# https://newsroom.spotify.com/2022-11-30/the-top-songs-artists-podcasts-and-listening-trends-of-2022/
