# %% [markdown]
# # Women's and Men's FIFA World Cup Data
#
# I collected this data from the wiki page for Womens FIFA World cup and the wiki page for Mens FIFA World Cup

# %%
import requests
import pandas as pd
import base64
import json
import urllib
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt

# %%
womens_world = pd.read_html('https://en.wikipedia.org/wiki/FIFA_Women%27s_World_Cup')

# %%
mens_world = pd.read_html('https://en.wikipedia.org/wiki/FIFA_World_Cup')

# %%
##womens_world

# %%
type(womens_world)
# Out:
# list

# %% [markdown]
# ## Confederation Comparisons
#
# ### Plan of analysis: I plan to try to compare the total of both of these charts in either a histagram or pie chart to help showcase which confederation has the most total wins. Once I have that part I will compare the top results together to see if they are the same or different for the Male and Female Conferderations.

# %% [markdown]
# The charts below is showing the different conference that compete in the FIFA World Cup and how many times they have won a cup, or if they have hosted in the past and when. Top is womens, bottom is mens

# %%
womens_world[3]
# Out:
#                                        Confederation  Total  \
# 0                 Asian Football Confederation (AFC)      3
# 1            Confederation of African Football (CAF)      0
# 2  Confederation of North, Central America and Ca...      3
# 3   South American Football Confederation (CONMEBOL)      0
# 4               Oceania Football Confederation (OFC)      1
# 5     Union of European Football Associations (UEFA)      3
#
#                                                Hosts
# 0            1991: China 2007: China 2023: Australia
# 1                                                NaN
# 2  1999: United States 2003: United States 2015: ...
# 3                                                NaN
# 4                                  2023: New Zealand
# 5            1995: Sweden 2011: Germany 2019: France

# %%
mens_world[2]
# Out:
#                                        Confederation  Total  \
# 0                 Asian Football Confederation (AFC)      2
# 1            Confederation of African Football (CAF)      2
# 2  Confederation of North, Central America and Ca...      4
# 3   South American Football Confederation (CONMEBOL)      5
# 4               Oceania Football Confederation (OFC)      0
# 5     Union of European Football Associations (UEFA)     12
# 6     Two competitions cancelled due to World War II      0
#
#                                                Hosts
# 0  2002: South Korea, Japan 2022: Qatar 2034: Sau...
# 1                   2010: South Africa 2030: Morocco
# 2  1970: Mexico 1986: Mexico 1994: United States ...
# 3  1930: Uruguay 1950: Brazil 1962: Chile 1978: A...
# 4                                                NaN
# 5  1934: Italy 1938: France 1954: Switzerland 195...
# 6                                          1942 1946

# %% [markdown]
# ## Total Attendance Comparision
#
# ### Plan of Analysis: I plan to compare the total attendance together separatly before then comparing the results together. From this I hope to find if there is either a specfic location that was more popular venue as well as if the attendence has grown through the years or stayed around the same. I think that the best way of displaying is to either use a scatter plot or a histagram.

# %% [markdown]
# The chart below is showcasing the different host countries for the Women's FIFA World Cup, the attendence at each of these events, the venue as well as some games. The chart one below is also showing the same information for the Men's FIFA World Cup as well

# %%
womens_world[4]
# Out:
#       Year                   Hosts Venues/ Cities Total attendance † Matches  \
#       Year                   Hosts Venues/ Cities Total attendance † Matches
# 0     1991                   China            6/4             510000      26
# 1     1995                  Sweden            5/5             112213      26
# 2     1999           United States            8/8            1214209      32
# 3     2003           United States            6/6             679664      32
# 4     2007                   China            5/5            1190971      32
# 5     2011                 Germany            9/9             845751      32
# 6     2015                  Canada            6/6            1353506      52
# 7     2019                  France            9/9            1131312      52
# 8     2023  Australia  New Zealand           10/9            1978274      64
# 9  Overall                 Overall        Overall            9015900     348
#
#   Average attendance Highest attendances  \
# ...

# %%
test_df = womens_world[4][womens_world[4]['Year'] != 'Overall']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 test_df = womens_world[4][womens_world[4]['Year'] != 'Overall']
#
# File ~/anaconda3/envs/data-f2023/lib/python3.11/site-packages/pandas/core/frame.py:3748, in DataFrame.__getitem__(self, key)
#    3746 # Do we have a (boolean) DataFrame?
#    3747 if isinstance(key, DataFrame):
# -> 3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
#
# File ~/anaconda3/envs/data-f2023/lib/python3.11/site-packages/pandas/core/frame.py:11527, in DataFrame.where(self, cond, other, inplace, axis, level)
#   11518 def where(
#   11519     self,
#   11520     cond,
#    (...)
#   11525     level: Level = None,
#   11526 ) -> DataFrame | None:
# > 11527     return super().where(
#   11528         cond,
#   11529         other,
# ...

# %%
fig9, ax9 = plt.subplots()
ax9.scatter(x = womens_world['Total attendance'], y = womens_world['Year'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 2
#       1 fig9, ax9 = plt.subplots()
# ----> 2 ax9.scatter(x = womens_world['Total attendance'], y = womens_world['Year'])
#       4 plt.show()
#
# TypeError: list indices must be integers or slices, not str

# %%
mens_world[3]
# Out:
#          Year                          Hosts Venues/ Cities  \
#          Year                          Hosts Venues/ Cities
# 0        1930                        Uruguay            3/1
# 1        1934                          Italy            8/8
# 2        1938                         France           10/9
# 3        1950                         Brazil            6/6
# 4        1954                    Switzerland            6/6
# 5        1958                         Sweden          12/12
# 6        1962                          Chile            4/4
# 7        1966                        England            8/7
# 8        1970                         Mexico            5/5
# 9        1974                   West Germany            9/9
# 10       1978                      Argentina            6/5
# 11       1982                          Spain          17/14
# 12       1986                         Mexico          12/11
# 13       1990                          Italy          12/12
# ...

# %% [markdown]
# ## Comparision of Champions and Runner ups
#
# ### Plan of Analysis:

# %% [markdown]
# The chart below is showcasing the winners and runnerups of the Women's FIFA World Cup, as well as the score of the final game and third place game. It also list the number of teams that where at each tournment throughout the years which allows to see how the tournment has grown from when it first started. The chart right below is showing the same information for the Men's FIFA World Cup as well.

# %%
womens_world[5]
# Out:
#   Ed.       Year                   Hosts          Final  \
#   Ed.       Year                   Hosts      Champions
# 0   1       1991                   China  United States
# 1   2       1995                  Sweden         Norway
# 2   3       1999           United States  United States
# 3   4  2003[n 2]           United States        Germany
# 4   5       2007                   China        Germany
# 5   6       2011                 Germany          Japan
# 6   7       2015                  Canada  United States
# 7   8       2019                  France  United States
# 8   9       2023  Australia  New Zealand          Spain
#
#                                                                      \
#                                                Score     Runners-up
# 0                      2–1 Tianhe Stadium, Guangzhou         Norway
# 1                         2–0 Råsunda Stadium, Solna        Germany
# 2           0–0 (a.e.t.) (5–4 p) Rose Bowl, Pasadena          China
# ...

# %%
mens_world[4]
# Out:
#    Ed.       Year                                Host  \
#    Ed.       Year                                Host
# 0    1       1930                             Uruguay
# 1    2       1934                               Italy
# 2    3       1938                              France
# 3    –       1942  (Not held because of World War II)
# 4    –       1946  (Not held because of World War II)
# 5    4       1950                              Brazil
# 6    5       1954                         Switzerland
# 7    6       1958                              Sweden
# 8    7       1962                               Chile
# 9    8       1966                             England
# 10   9       1970                              Mexico
# 11  10       1974                        West Germany
# 12  11       1978                           Argentina
# 13  12       1982                               Spain
# 14  13       1986                              Mexico
# ...

# %% [markdown]
# ## Comparisions of countries and who has won the most tournments
#
# ### Plan of Analysis: I plan to display this information in a pie chart or histagram separatly and then compare the top 5 of each tournment together in a 2 plot histagram.

# %% [markdown]
# The charts below is showing the country that has had the most wins in the tournment from most to least as well as listing the year they have won as well.

# %%
womens_world[6]
# Out:
#              Team                     Title(s) Runners-up  \
# 0   United States  4 (1991, 1999*, 2015, 2019)   1 (2011)
# 1         Germany               2 (2003, 2007)   1 (1995)
# 2          Norway                     1 (1995)   1 (1991)
# 3           Japan                     1 (2011)   1 (2015)
# 4           Spain                     1 (2023)        NaN
# 5          Sweden                          NaN   1 (2003)
# 6         England                          NaN   1 (2023)
# 7          Brazil                          NaN   1 (2007)
# 8           China                          NaN   1 (1999)
# 9     Netherlands                          NaN   1 (2019)
# 10         Canada                          NaN        NaN
# 11         France                          NaN        NaN
# 12      Australia                          NaN        NaN
#
#                    Third place    Fourth place  Top 4 total
# 0        3 (1995, 2003*, 2007)             NaN            8
# ...

# %%
fig6, ax6 = plt.subplots()
ax6.pie(womens_world[6]['Top 4 total'])

plt.show()

# %%
mens_world[5]
# Out:
#                Team                            Titles  \
# 0            Brazil  5 (1958, 1962, 1970, 1994, 2002)
# 1          Germany1       4 (1954, 1974*, 1990, 2014)
# 2             Italy       4 (1934*, 1938, 1982, 2006)
# 3         Argentina             3 (1978*, 1986, 2022)
# 4            France                   2 (1998*, 2018)
# 5           Uruguay                   2 (1930*, 1950)
# 6           England                         1 (1966*)
# 7             Spain                          1 (2010)
# 8       Netherlands                               NaN
# 9           Hungary                               NaN
# 10  Czech Republic2                               NaN
# 11           Sweden                               NaN
# 12          Croatia                               NaN
# 13           Poland                               NaN
# 14          Austria                               NaN
# 15         Portugal                               NaN
# ...

# %%
fig8, ax8 = plt.subplots()
ax8.hist(mens_world['Top 4 total'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 fig8, ax8 = plt.subplots()
# ----> 2 ax8.hist(mens_world['Top 4 total'])
#       4 plt.show()
#
# TypeError: list indices must be integers or slices, not str

# %%
fig7, ax7 = plt.subplots()
ax7.pie(mens_world[5]['Top 4 total'])

plt.show()

# %% [markdown]
# ## Comparsion of which confederation has had the most wins
#
# ### Plan of Analysis: I plan on displaying these charts in a bar plot based on champions, runners-up, etc. I feel that by placing them in a bar plot it will be easy to see the differences between the confederations.

# %% [markdown]
# The charts below is showing the different conferences have placed throughout the years the tournment, allowing for to see if one conference is better than another

# %%
womens_world[7]
# Out:
#          Confederation  AFC  CAF  CONCACAF  CONMEBOL  OFC  UEFA
# 0            Champions    1    0         4         0    0     4
# 1           Runners-up    2    0         1         1    0     5
# 2          Third place    0    0         3         1    0     5
# 3         Fourth place    2    0         1         0    0     6
# 4            Finalists    3    0         5         1    0     9
# 5       Semi-finalists    5    0         9         2    0    20
# 6    Quarter-finalists   16    1        10         5    0    40
# 7  Top 16 (since 2015)    9    6         6         4    0    23
# 8           Qualifiers   35   20        26        18    9    60

# %%
mens_world[6]
# Out:
#   Confederation  AFC  CAF  CONCACAF  CONMEBOL  OFC  UEFA  Total
# 0         Teams   43   49        46        89    4   258    489
# 1        Top 16    9   11        15        37    1    99    172
# 2         Top 8    2    4         5        36    0   105    152
# 3         Top 4    1    1         1        23    0    62     88
# 4         Top 2    0    0         0        15    0    29     44
# 5           4th    1    1         0         5    0    15     22
# 6           3rd    0    0         1         3    0    18     22
# 7           2nd    0    0         0         5    0    17     22
# 8           1st    0    0         0        10    0    12     22

# %%
fig1, ax1 = plt.subplots()
ax1.pie(mens_world[6]['AFC'])
ax1.pie(womens_world[7]['AFC'])

plt.show()

# %% [markdown]
# ## Comparision of the highest goal score player
#
# ### Plan of Analysis: I do feel that comparing these charts isn't fully fair as the women's chart is missing some information that would be helpful to have that the mens have. I do think however it will be interesting to compare and analysis the data to see which tournment has the highest goal scorers. I think the best way to display this will either by in a scatter plot, histgram or bar plot.

# %% [markdown]
# The charts below is data based on the best ranked womens player that has played in the FIFA World Cup at one point in time.

# %%
womens_world[8]
# Out:
#    Rank               Player  Goals scored
# 0     1                Marta            17
# 1     2         Birgit Prinz            14
# 2     2         Abby Wambach            14
# 3     4       Michelle Akers            12
# 4     5            Cristiane            11
# 5     5              Sun Wen            11
# 6     5     Bettina Wiegmann            11
# 7     8   Christine Sinclair            10
# 8     8  Ann Kristin Aarønes            10
# 9     8          Carli Lloyd            10

# %%
fig3, ax3 = plt.subplots()
ax3.pie(womens_world[8]['Goals scored'])

plt.show()

# %%
mens_world[7]
# Out:
#     Rank             Player  Goals  Matches  Goals per game
# 0      1     Miroslav Klose     16       24            0.67
# 1      2            Ronaldo     15       19            0.84
# 2      3        Gerd Müller     14       13            1.08
# 3      4      Just Fontaine     13        6            2.17
# 4      4       Lionel Messi     13       26            0.50
# 5      6      Kylian Mbappé     12       14            0.86
# 6      6               Pelé     12       14            0.86
# 7      8      Sándor Kocsis     11        5            2.20
# 8      8   Jürgen Klinsmann     11       17            0.65
# 9     10        Helmut Rahn     10       10            1.00
# 10    10  Gabriel Batistuta     10       12            0.83
# 11    10       Gary Lineker     10       12            0.83
# 12    10   Teófilo Cubillas     10       13            0.77
# 13    10      Thomas Müller     10       19            0.53
# 14    10      Grzegorz Lato     10       20            0.50

# %%
fig2, ax2 = plt.subplots()
ax2.pie(mens_world[7]['Goals'])

plt.show()

# %% [markdown]
# ## Comparision of which country has had the most goals
#
# ### Plan of Analysis: These charts will be able to analyize against each other but also bringing the conferdation graphs down to then compare together which teams were the ones giving those conferdations wins. For this I think pie charts would work, but I think it could be made neater by using histograms or bar graphs to better see which country has had the most wins. When comparing to the conferederations though, a pie chart might be an intersting way to look at it.

# %% [markdown]
# The chart below is for the number of goals each country has scored in the FIFA World Cup ranked from most to least

# %%
womens_world[9]
# Out:
#    Rank        Country  Goals scored
# 0     1  United States           142
# 1     2        Germany           129
# 2     3         Norway           100
# 3     4         Sweden            83
# 4     5         Brazil            71
# 5     6        England            56
# 6     7          China            55
# 7     8          Japan            54
# 8     9      Australia            48
# 9    10         France            44

# %%
fig4, ax4 = plt.subplots()
ax4.pie(womens_world[9]['Goals scored'])

plt.show()

# %%
mens_world[8]
# Out:
#    Rank National team  Goals scored
# 0     1        Brazil           237
# 1     2       Germany           232
# 2     3     Argentina           152
# 3     4        France           136
# 4     5         Italy           128
# 5     6         Spain           108
# 6     7       England           104
# 7     8   Netherlands            96
# 8     9       Uruguay            89
# 9    10       Hungary            87

# %%
fig5, ax5 = plt.subplots()
ax5.pie(mens_world[8]['Goals scored'])

plt.show()

# %% [markdown]
# ## Comparision of special awards in the Cup
#
# ### Plan of Analysis: I think by analizing these charts, it will be able to see which player in which country the best player of the matches came from. I am not quite sure how to go about displaying this in a way that will be benefial currently, so I might cut this from my final project.

# %% [markdown]
# The charts below is for the awards that are given in the FIFA World Cup that shows the best goal scorer (Golden Boot) best goalie (Golden Glove) and other facts about these as well.

# %%
womens_world[10]
# Out:
#                     World Cup     Golden Ball          Golden Boot  Goals  \
# 0                  1991 China  Carin Jennings       Michelle Akers     10
# 1                 1995 Sweden      Hege Riise  Ann Kristin Aarønes      6
# 2          1999 United States         Sun Wen       Sun Wen  Sissi      7
# 3          2003 United States    Birgit Prinz         Birgit Prinz      7
# 4                  2007 China           Marta                Marta      7
# 5                2011 Germany     Homare Sawa          Homare Sawa      5
# 6                 2015 Canada     Carli Lloyd          Célia Šašić      6
# 7                 2019 France   Megan Rapinoe        Megan Rapinoe      6
# 8  2023 Australia/New Zealand  Aitana Bonmatí      Hinata Miyazawa      5
#
#               Golden Glove  Clean sheets FIFA Young Player Award  \
# 0              Not awarded           NaN             Not awarded
# 1              Not awarded           NaN             Not awarded
# ...

# %%
mens_world[9]
# Out:
#                  World Cup          Golden Ball  \
# 0             1930 Uruguay          Not Awarded
# 1               1934 Italy          Not Awarded
# 2              1938 France          Not Awarded
# 3              1950 Brazil          Not Awarded
# 4         1954 Switzerland          Not Awarded
# 5              1958 Sweden          Not Awarded
# 6               1962 Chile          Not Awarded
# 7             1966 England          Not Awarded
# 8              1970 Mexico          Not Awarded
# 9        1974 West Germany          Not Awarded
# 10          1978 Argentina          Not Awarded
# 11              1982 Spain          Paolo Rossi
# 12             1986 Mexico       Diego Maradona
# 13              1990 Italy  Salvatore Schillaci
# 14      1994 United States              Romário
# 15             1998 France              Ronaldo
# 16  2002 South Korea/Japan          Oliver Kahn
# 17            2006 Germany      Zinedine Zidane
# ...
