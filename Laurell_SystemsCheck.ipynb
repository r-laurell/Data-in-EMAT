# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### Header 6

# %% [markdown]
# ### From this class I hope to gain
# 1. knowledge in jupyter notebook
# 2. knowledge in college data and displaying it
# 3. learning how to display data using jupyter notebook

# %% [markdown]
# ___Bold and Italic___
# __Bold__
# _Italic_

# %% [markdown]
# ![IMG_0616.JPG](attachment:IMG_0616.JPG)
